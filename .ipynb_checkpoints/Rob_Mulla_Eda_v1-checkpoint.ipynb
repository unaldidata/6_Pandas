# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 1

# %%
df.shape
# Out:
# (891, 15)

# %%
df.head(8)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df = df[['survived', 
    'pclass', 
    'sex', 
    'age', 
    # 'sibsp', 
    # 'parch', 
    'fare',
    'embarked', 
    'class', 
    'who', 
    # 'adult_male', 
    'deck', 
    'embark_town',
    'alive', 
    'alone']]
df
# Out:
#      survived  pclass     sex   age     fare embarked   class    who deck  \
# 0           0       3    male  22.0   7.2500        S   Third    man  NaN
# 1           1       1  female  38.0  71.2833        C   First  woman    C
# 2           1       3  female  26.0   7.9250        S   Third  woman  NaN
# 3           1       1  female  35.0  53.1000        S   First  woman    C
# 4           0       3    male  35.0   8.0500        S   Third    man  NaN
# ..        ...     ...     ...   ...      ...      ...     ...    ...  ...
# 886         0       2    male  27.0  13.0000        S  Second    man  NaN
# 887         1       1  female  19.0  30.0000        S   First  woman    B
# 888         0       3  female   NaN  23.4500        S   Third  woman  NaN
# 889         1       1    male  26.0  30.0000        C   First    man    C
# 890         0       3    male  32.0   7.7500        Q   Third    man  NaN
#
#      embark_town alive  alone
# 0    Southampton    no  False
# ...

# %%
# df.drop(["alive"] , axis = 1)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# fare            float64
# embarked         object
# class          category
# who              object
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
pd.to_numeric(df['pclass'])
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
# rename our columns...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked', 'class', 'who',
#        'deck', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
df = df.rename(columns = {"survived" : "hayatta_kalan", 'embarked' : "Biniş_Limanı"})
df
# Out:
#      hayatta_kalan  pclass     sex   age     fare Biniş_Limanı   class    who  \
# 0                0       3    male  22.0   7.2500            S   Third    man
# 1                1       1  female  38.0  71.2833            C   First  woman
# 2                1       3  female  26.0   7.9250            S   Third  woman
# 3                1       1  female  35.0  53.1000            S   First  woman
# 4                0       3    male  35.0   8.0500            S   Third    man
# ..             ...     ...     ...   ...      ...          ...     ...    ...
# 886              0       2    male  27.0  13.0000            S  Second    man
# 887              1       1  female  19.0  30.0000            S   First  woman
# 888              0       3  female   NaN  23.4500            S   Third  woman
# 889              1       1    male  26.0  30.0000            C   First    man
# 890              0       3    male  32.0   7.7500            Q   Third    man
#
# ...

# %%
df.isna().sum()
# Out:
# hayatta_kalan      0
# pclass             0
# sex                0
# age              177
# fare               0
# Biniş_Limanı       2
# class              0
# who                0
# deck             688
# embark_town        2
# alive              0
# alone              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.loc[df.duplicated(subset =["name"] )]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\1947612182.py in ?()
# ----> 1 df.loc[df.duplicated(subset =["name"] )]
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#    6953             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['name'], dtype='object')

# %%
# checking an example duplicate
df.query ("Coaster_Name == "Crystal Beach Cyclone"")
# Out:
#   Cell In[91], line 2
#     df.query ("Coaster_Name == "Crystal Beach Cyclone"")
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.columns
# Out:
# Index(['hayatta_kalan', 'pclass', 'sex', 'age', 'fare', 'Biniş_Limanı',
#        'class', 'who', 'deck', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
~df.duplicated().sum()
# Out:
# -108

# %%
df
# Out:
#      hayatta_kalan  pclass     sex   age     fare Biniş_Limanı   class    who  \
# 0                0       3    male  22.0   7.2500            S   Third    man
# 1                1       1  female  38.0  71.2833            C   First  woman
# 2                1       3  female  26.0   7.9250            S   Third  woman
# 3                1       1  female  35.0  53.1000            S   First  woman
# 4                0       3    male  35.0   8.0500            S   Third    man
# ..             ...     ...     ...   ...      ...          ...     ...    ...
# 886              0       2    male  27.0  13.0000            S  Second    man
# 887              1       1  female  19.0  30.0000            S   First  woman
# 888              0       3  female   NaN  23.4500            S   Third  woman
# 889              1       1    male  26.0  30.0000            C   First    man
# 890              0       3    male  32.0   7.7500            Q   Third    man
#
# ...

# %%
df["embark_town"].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["class"].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
df["alive"].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
df["hayatta_kalan"].value_counts()
# Out:
# hayatta_kalan
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
ax = df["hayatta_kalan"].value_counts().plot(kind = 'bar' , title = "Titanic'ten Hayatta Kalanlar ve Gidenler")

ax.set_ylabel ("Kişi Sayısı") 
ax.set_xlabel ("Ölen ve Kalan")
# Out:
# Text(0.5, 0, 'Ölen ve Kalan')

# %%
df["hayatta_kalan"].value_counts().plot(kind = 'barh')
# Out:
# <Axes: ylabel='hayatta_kalan'>

# %%
ax = df["embark_town"].value_counts().plot(kind = 'bar' , title = "Biniş Limanı Chart'ı")

ax.set_ylabel ("Kişi Sayısı")
ax.set_xlabel ("Hangi Limandan Bindiği")
# Out:
# Text(0.5, 0, 'Hangi Limandan Bindiği')

# %%
df.plot(kind = "scatter" ,
        x = "embark_town" ,
       y = "hayatta_kalan" ,
       title = "hangi limandan binenlerin ne kadar hayatta kaldığı")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 df.plot(kind = "scatter" ,
#       2         x = "embark_town" ,
#       3        y = "hayatta_kalan" ,
#       4        title = "hangi limandan binenlerin ne kadar hayatta kaldığı")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
sns.scatterplot()

# %%
df.head()
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[158], line 2
#       1 df.head()
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
df[["embark_town" , "hayatta_kalan"]].dropna() #.corr()
# Out:
#      embark_town  hayatta_kalan
# 0    Southampton              0
# 1      Cherbourg              1
# 2    Southampton              1
# 3    Southampton              1
# 4    Southampton              0
# ..           ...            ...
# 886  Southampton              0
# 887  Southampton              1
# 888  Southampton              0
# 889    Cherbourg              1
# 890   Queenstown              0
#
# [889 rows x 2 columns]

# %%
df
# Out:
#      hayatta_kalan  pclass     sex   age     fare Biniş_Limanı   class    who  \
# 0                0       3    male  22.0   7.2500            S   Third    man
# 1                1       1  female  38.0  71.2833            C   First  woman
# 2                1       3  female  26.0   7.9250            S   Third  woman
# 3                1       1  female  35.0  53.1000            S   First  woman
# 4                0       3    male  35.0   8.0500            S   Third    man
# ..             ...     ...     ...   ...      ...          ...     ...    ...
# 886              0       2    male  27.0  13.0000            S  Second    man
# 887              1       1  female  19.0  30.0000            S   First  woman
# 888              0       3  female   NaN  23.4500            S   Third  woman
# 889              1       1    male  26.0  30.0000            C   First    man
# 890              0       3    male  32.0   7.7500            Q   Third    man
#
# ...

# %%
df["hayatta_kalan"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='hayatta_kalan'>

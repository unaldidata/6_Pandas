# %% [markdown]
# ## Mert Hocam; bu çalışmayı yaparken:
# ## Rob Mulla'nın Pandas EDA videosundan faydalandım.

# %%
import matplotlib.pylab as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
plt.style.use("ggplot")

# %% [markdown]
# #### Step 1: Data Understanding
# #### DataFrame Shape
# #### Head and tail
# #### dtypes
# #### describe

# %%
df = pd.read_csv("data.csv", encoding="unicode_escape")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  535874.000000  535874.000000  403182.000000
# mean        9.587927       4.636533   15287.687868
# std       153.292222      97.302232    1714.009551
# min    -74215.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13952.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     74215.000000   38970.000000   18287.000000

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head(8)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES       2.0
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER       6.0
# 7    536366     22633               HAND WARMER UNION JACK       6.0
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity       float64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  535874.000000  535874.000000  403182.000000
# mean        9.587927       4.636533   15287.687868
# std       153.292222      97.302232    1714.009551
# min    -74215.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13952.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     74215.000000   38970.000000   18287.000000

# %%
##### Step 2 Data Preparation
# Dropping irrelevant coluns and rows
# Identfying duplicated columns
# Remaming Columns
# Feature Creation

# %%
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                 WHITE METAL LANTERN       6.0
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER       8.0
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df[['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
       'UnitPrice', 'CustomerID', 'Country']]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[['InvoiceNo', 
    #'StockCode', "we have commented out "stockcode""
    'Description', 'Quantity', 'InvoiceDate',
       'UnitPrice', 'CustomerID', 'Country']]
# eğer bunun sonuna .copy() yazarsak StockCode tamamen gider elimizdeki yepyeni bir dataframe olur.
# Out:
#        InvoiceNo                          Description  Quantity  \
# 0         536365   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365                  WHITE METAL LANTERN       6.0
# 2         536365       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...                                  ...       ...
# 541904    581587          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
# df.drop(['Description'], axis = 1 )
# Example of dropping a simple column.

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity       float64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity              float64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Rename our columns

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df = df.rename({'InvoiceNo': 'Invoice_No', 'StockCode': 'Stock_Code'}, axis=1)

# %%
df.head(2)
# Out:
#   Invoice_No Stock_Code                         Description  Quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1     536365      71053                 WHITE METAL LANTERN       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.isna().sum()
# Out:
# Invoice_No          0
# Stock_Code       6035
# Description      7489
# Quantity         6035
# InvoiceDate      6035
# UnitPrice        6035
# CustomerID     138727
# Country          6035
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %%
df.duplicated().sum()
# inanılmaz tam 5268 adet birbirinin aynı satır mevcut hem de tıpatıp. :)
# Out:
# 5268

# %%
df.loc[df.duplicated(subset = ['Description'])]
# Out:
#        Invoice_No Stock_Code                         Description  Quantity  \
# 47         536372      22632           HAND WARMER RED POLKA DOT       6.0
# 48         536372      22633              HAND WARMER UNION JACK       6.0
# 49         536373     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 50         536373      71053                 WHITE METAL LANTERN       6.0
# 51         536373     84406B      CREAM CUPID HEARTS COAT HANGER       8.0
# ...           ...        ...                                 ...       ...
# 541904     581587      22613         PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905     581587      22899        CHILDREN'S APRON DOLLY GIRL        6.0
# 541906     581587      23254       CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907     581587      23255     CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908     581587      22138       BAKING SET 9 PIECE RETROSPOT        3.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.loc[df.duplicated(subset = ['Description'])].head(4)
# Out:
#    Invoice_No Stock_Code                         Description  Quantity  \
# 47     536372      22632           HAND WARMER RED POLKA DOT       6.0
# 48     536372      22633              HAND WARMER UNION JACK       6.0
# 49     536373     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 50     536373      71053                 WHITE METAL LANTERN       6.0
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 47 2010-12-01 09:01:00       1.85     17850.0  United Kingdom
# 48 2010-12-01 09:01:00       1.85     17850.0  United Kingdom
# 49 2010-12-01 09:02:00       2.55     17850.0  United Kingdom
# 50 2010-12-01 09:02:00       3.39     17850.0  United Kingdom

# %%
df.query('Description == "HAND WARMER RED POLKA DOT"')
# Out:
#      Invoice_No Stock_Code                Description  Quantity  \
# 8        536366      22632  HAND WARMER RED POLKA DOT       6.0
# 47       536372      22632  HAND WARMER RED POLKA DOT       6.0
# 84       536377      22632  HAND WARMER RED POLKA DOT       6.0
# 315      536399      22632  HAND WARMER RED POLKA DOT       6.0
# 433      536407      22632  HAND WARMER RED POLKA DOT       6.0
# 3130     536601      22632  HAND WARMER RED POLKA DOT       6.0
# 3144     536603      22632  HAND WARMER RED POLKA DOT       6.0
# 3208     536610      22632  HAND WARMER RED POLKA DOT       6.0
# 3256     536614      22632  HAND WARMER RED POLKA DOT       6.0
# 3441     536629      22632  HAND WARMER RED POLKA DOT       6.0
# 3459     536631      22632  HAND WARMER RED POLKA DOT       6.0
# 3821     536688      22632  HAND WARMER RED POLKA DOT       6.0
# 3840     536693      22632  HAND WARMER RED POLKA DOT       6.0
# 4180     536751      22632  HAND WARMER RED POLKA DOT       6.0
# ...

# %%
df.query('Description == "HAND WARMER RED POLKA DOT"').sum
# bu satırlar birbirinin aynısı gibi gözükse de invoice date a baktığımızda farklı olduğu gözüküyor.
# Out:
# <bound method DataFrame.sum of      Invoice_No Stock_Code                Description  Quantity  \
# 8        536366      22632  HAND WARMER RED POLKA DOT       6.0
# 47       536372      22632  HAND WARMER RED POLKA DOT       6.0
# 84       536377      22632  HAND WARMER RED POLKA DOT       6.0
# 315      536399      22632  HAND WARMER RED POLKA DOT       6.0
# 433      536407      22632  HAND WARMER RED POLKA DOT       6.0
# 3130     536601      22632  HAND WARMER RED POLKA DOT       6.0
# 3144     536603      22632  HAND WARMER RED POLKA DOT       6.0
# 3208     536610      22632  HAND WARMER RED POLKA DOT       6.0
# 3256     536614      22632  HAND WARMER RED POLKA DOT       6.0
# 3441     536629      22632  HAND WARMER RED POLKA DOT       6.0
# 3459     536631      22632  HAND WARMER RED POLKA DOT       6.0
# 3821     536688      22632  HAND WARMER RED POLKA DOT       6.0
# 3840     536693      22632  HAND WARMER RED POLKA DOT       6.0
# ...

# %%
df.columns
# Out:
# Index(['Invoice_No', 'Stock_Code', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# df.shape

# %%
# Step 3 : Feature Understanding
# Univariate analysis
# Plotting Feature Distributions
# Histograms
# KDE 
# Boxplot

# %%
df.head(2)
# Out:
#   Invoice_No Stock_Code                         Description  Quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1     536365      71053                 WHITE METAL LANTERN       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df['InvoiceDate'].value_counts().sum()
# Out:
# 535874

# %%
duplicates = df[df['Invoice_No'].duplicated()]
duplicates.head(15)
# Out:
#    Invoice_No Stock_Code                          Description  Quantity  \
# 1      536365      71053                  WHITE METAL LANTERN       6.0
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5      536365      22752         SET 7 BABUSHKA NESTING BOXES       2.0
# 6      536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER       6.0
# 8      536366      22632            HAND WARMER RED POLKA DOT       6.0
# 10     536367      22745           POPPY'S PLAYHOUSE BEDROOM        6.0
# 11     536367      22748            POPPY'S PLAYHOUSE KITCHEN       6.0
# 12     536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL       8.0
# 13     536367      22310              IVORY KNITTED MUG COSY        6.0
# 14     536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS       6.0
# ...

# %%
df['Description'].value_counts() # hangi üründen toplam ne kadar satış yapıldığına bakıyoruz.
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# VINTAGE BEAD PINK JEWEL STAND            1
# MISELTOE HEART WREATH CREAM              1
# incorrectly put back into stock          1
# DOORKNOB CERAMIC IVORY                   1
# BLACKCHRISTMAS TREE 30CM                 1
# Name: count, Length: 4113, dtype: int64

# %%
df['Description'].value_counts().head(10) # en çok satan 10 üründen kaç adet satıldı.
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
# ASSORTED COLOUR BIRD ORNAMENT         1501
# SET OF 3 CAKE TINS PANTRY DESIGN      1473
# PACK OF 72 RETROSPOT CAKE CASES       1385
# LUNCH BAG  BLACK SKULL.               1350
# NATURAL SLATE HEART CHALKBOARD        1280
# Name: count, dtype: int64

# %%
df['Description'].value_counts().head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Description'>

# %%
# bu çizgiler dikey değil de yatay olsun...
df['Description'].value_counts().head(10).plot(kind = "barh")
# Out:
# <Axes: ylabel='Description'>

# %%
df['Description'].value_counts().head(10).plot(kind = "bar", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı" )
# Out:
# <Axes: title={'center': 'En Çok Satılan 10 Üründen Kaç Adet Satıldı'}, xlabel='Description'>

# %%
df['Description'].value_counts().head(10).plot(kind = "barh", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı" )
# Out:
# <Axes: title={'center': 'En Çok Satılan 10 Üründen Kaç Adet Satıldı'}, ylabel='Description'>

# %%
df['Description'].value_counts().head(10).plot(kind = "bar", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı" )
# Out:
# <Axes: title={'center': 'En Çok Satılan 10 Üründen Kaç Adet Satıldı'}, xlabel='Description'>

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "bar", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı").ax.set_xlabel('Ürünler').ax.set_ylabel('Satış Sayısı')

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "bar", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı")
ax.set_xlabel('Ürünler')
ax.set_ylabel('Satış Sayısı')
# Out:
# Text(0, 0.5, 'Satış Sayısı')

# %%
df.columns
# Out:
# Index(['Invoice_No', 'Stock_Code', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df['Quantity']
# Out:
# 0          6.0
# 1          6.0
# 2          8.0
# 3          6.0
# 4          6.0
#           ...
# 541904    12.0
# 541905     6.0
# 541906     4.0
# 541907     4.0
# 541908     3.0
# Name: Quantity, Length: 541909, dtype: float64

# %%
df.head(4)
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1     536365      71053                  WHITE METAL LANTERN       6.0
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df['Description'].value_counts().head(10).plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "hist", color = "orange", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı")
ax.set_xlabel('Ürünler')
ax.set_ylabel('Satış Sayısı')
# Out:
# Text(0, 0.5, 'Satış Sayısı')

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "hist", bins = 20, color = "orange", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı")
ax.set_xlabel('Ürünler')
ax.set_ylabel('Satış Sayısı')
# Out:
# Text(0, 0.5, 'Satış Sayısı')

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "bar", color = "yellow",  title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı")
ax.set_xlabel('Ürünler')
ax.set_ylabel('Satış Sayısı')
# Out:
# Text(0, 0.5, 'Satış Sayısı')

# %%
ax = df['Description'].value_counts().head(10).plot(kind = "kde",  color = "magenta", title ="En Çok Satılan 10 Üründen Kaç Adet Satıldı")
ax.set_xlabel('Ürünler')
ax.set_ylabel('Satış Sayısı')
# Out:
# Text(0, 0.5, 'Satış Sayısı')

# %%
# Step 4: Feature Relationship
# Scatterplot
# Heatmap Correlation
# Pairplot
# Gropupby Comprarisons

# %%
df.head(2)
# Out:
#   Invoice_No Stock_Code                         Description  Quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1     536365      71053                 WHITE METAL LANTERN       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
a = sns.scatterplot(x = "Description" , y = 'Quantity', data = df)
a
# Out:
# <Axes: xlabel='Description', ylabel='Quantity'>

# %%
df.head(3)
# Out:
#   Invoice_No Stock_Code                         Description  Quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1     536365      71053                 WHITE METAL LANTERN       6.0
# 2     536365     84406B      CREAM CUPID HEARTS COAT HANGER       8.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df[['UnitPrice','Quantity','Invoice_No']].dropna()
# Out:
#         UnitPrice  Quantity Invoice_No
# 0            2.55       6.0     536365
# 1            3.39       6.0     536365
# 2            2.75       8.0     536365
# 3            3.39       6.0     536365
# 4            3.39       6.0     536365
# ...           ...       ...        ...
# 541904       0.85      12.0     581587
# 541905       2.10       6.0     581587
# 541906       4.15       4.0     581587
# 541907       4.15       4.0     581587
# 541908       4.95       3.0     581587
#
# [535874 rows x 3 columns]

# %%
df['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# VINTAGE BEAD PINK JEWEL STAND            1
# MISELTOE HEART WREATH CREAM              1
# incorrectly put back into stock          1
# DOORKNOB CERAMIC IVORY                   1
# BLACKCHRISTMAS TREE 30CM                 1
# Name: count, Length: 4113, dtype: int64

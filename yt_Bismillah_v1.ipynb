# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140
# python                : 3.12.7.final.0
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : Intel64 Family 6 Model 142 Stepping 12, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : Turkish_Türkiye.1254
#
# pandas                : 2.2.2
# numpy                 : 1.26.4
# pytz                  : 2024.1
# dateutil              : 2.9.0.post0
# setuptools            : 75.1.0
# pip                   : 24.2
# Cython                : None
# pytest                : 7.4.4
# hypothesis            : None
# sphinx                : 7.3.7
# blosc                 : None
# feather               : None
# xlsxwriter            : None
# lxml.etree            : 5.2.1
# ...

# %%
df = pd.DataFrame({"col_one" : [100, 200], "col_two"  : [300, 400]})
df
# Out:
#    col_one  col_two
# 0      100      300
# 1      200      400

# %%
df = df.rename({"col_one" : "deneme" , "col_two" : "123"}, axis = "columns")
df
# Out:
#    deneme  123
# 0     100  300
# 1     200  400

# %%
# ilave olarak replace metodu da vardır.

# %%
df.add_prefix("x__")
# Out:
#    x__deneme  x__123
# 0        100     300
# 1        200     400

# %%
df.add_suffix("__y")
# Out:
#    deneme__y  123__y
# 0        100     300
# 1        200     400

# %%
df_deneme = pd. DataFrame (np.random.rand(4,8), columns = list("abcdefgh"))
df_deneme
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.467695  0.265423  0.333327  0.272008  0.579024  0.859807  0.576500
# 1  0.750145  0.182483  0.438395  0.965349  0.761271  0.484259  0.611649
# 2  0.651885  0.222619  0.335796  0.231810  0.012988  0.330587  0.601665
# 3  0.411271  0.569582  0.711737  0.406744  0.642944  0.744085  0.221527
#
#           h
# 0  0.011511
# 1  0.812660
# 2  0.614826
# 3  0.417579

# %%
df_deneme.head(2)
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.467695  0.265423  0.333327  0.272008  0.579024  0.859807  0.576500
# 1  0.750145  0.182483  0.438395  0.965349  0.761271  0.484259  0.611649
#
#           h
# 0  0.011511
# 1  0.812660

# %%
df_deneme.loc[::-1].head(3)
# Out:
#           a         b         c         d         e         f         g  \
# 3  0.411271  0.569582  0.711737  0.406744  0.642944  0.744085  0.221527
# 2  0.651885  0.222619  0.335796  0.231810  0.012988  0.330587  0.601665
# 1  0.750145  0.182483  0.438395  0.965349  0.761271  0.484259  0.611649
#
#           h
# 3  0.417579
# 2  0.614826
# 1  0.812660

# %%
df_deneme.loc[::-1].reset_index(drop = True).head(3)
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.411271  0.569582  0.711737  0.406744  0.642944  0.744085  0.221527
# 1  0.651885  0.222619  0.335796  0.231810  0.012988  0.330587  0.601665
# 2  0.750145  0.182483  0.438395  0.965349  0.761271  0.484259  0.611649
#
#           h
# 0  0.417579
# 1  0.614826
# 2  0.812660

# %%
df_deneme.loc[:, : : -1].head()
# Out:
#           h         g         f         e         d         c         b  \
# 0  0.011511  0.576500  0.859807  0.579024  0.272008  0.333327  0.265423
# 1  0.812660  0.611649  0.484259  0.761271  0.965349  0.438395  0.182483
# 2  0.614826  0.601665  0.330587  0.012988  0.231810  0.335796  0.222619
# 3  0.417579  0.221527  0.744085  0.642944  0.406744  0.711737  0.569582
#
#           a
# 0  0.467695
# 1  0.750145
# 2  0.651885
# 3  0.411271

# %%
# df_deneme.loc[:, : : -1].head() virgülden önceki : tüm rowları seç manasına gelir.

# %%
df_deneme.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# e    float64
# f    float64
# g    float64
# h    float64
# dtype: object

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[::-1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[::-1].reset_index(drop = True).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0         0       3    male  32.0      0      0   7.75        Q   Third
# 1         1       1    male  26.0      0      0  30.00        C   First
# 2         0       3  female   NaN      1      2  23.45        S   Third
# 3         1       1  female  19.0      0      0  30.00        S   First
# 4         0       2    male  27.0      0      0  13.00        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN   Queenstown    no   True
# 1    man        True    C    Cherbourg   yes   True
# 2  woman       False  NaN  Southampton    no  False
# 3  woman       False    B  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[: , ::-1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.select_dtypes(include = "object"  ).head(8)
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no
# 5    male        Q    man   Queenstown    no
# 6    male        S    man  Southampton    no
# 7    male        S  child  Southampton    no

# %%
df.select_dtypes(include = ["object" , "number" , "category" , "datetime"]).head(8)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who deck  embark_town alive
# 0    man  NaN  Southampton    no
# 1  woman    C    Cherbourg   yes
# 2  woman  NaN  Southampton   yes
# 3  woman    C  Southampton   yes
# 4    man  NaN  Southampton    no
# 5    man  NaN   Queenstown    no
# 6    man    E  Southampton    no
# 7  child  NaN  Southampton    no

# %%
df.select_dtypes (exclude = "int") . head (7)
# Out:
#       sex   age     fare embarked  class    who  adult_male deck  embark_town  \
# 0    male  22.0   7.2500        S  Third    man        True  NaN  Southampton
# 1  female  38.0  71.2833        C  First  woman       False    C    Cherbourg
# 2  female  26.0   7.9250        S  Third  woman       False  NaN  Southampton
# 3  female  35.0  53.1000        S  First  woman       False    C  Southampton
# 4    male  35.0   8.0500        S  Third    man        True  NaN  Southampton
# 5    male   NaN   8.4583        Q  Third    man        True  NaN   Queenstown
# 6    male  54.0  51.8625        S  First    man        True    E  Southampton
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True
# 3   yes  False
# 4    no   True
# 5    no   True
# 6    no   True

# %%
# reduce dataframe size

# %%
df.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   col_one    3 non-null      float64
#  1   col_two    3 non-null      float64
#  2   col_three  3 non-null      float64
# dtypes: float64(3)
# memory usage: 204.0 bytes

# %%
df = pd.DataFrame({'col_one':['1.1', '2.2', '3.3'],
                   'col_two':['4.4', '5.5', '6.6'],
                   'col_three':['7.7', '8.8', '-']})
df
# Out:
#   col_one col_two col_three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
df.dtypes
# Out:
# col_one      object
# col_two      object
# col_three    object
# dtype: object

# %%
df.astype({"col_one" : "float" , "col_two" : "float"}).dtypes
# Out:
# col_one      float64
# col_two      float64
# col_three     object
# dtype: object

# %%
pd.to_numeric(df.col_three, errors = "coerce").fillna(0)
# Out:
# 0    7.7
# 1    8.8
# 2    0.0
# Name: col_three, dtype: float64

# %%
df = df.apply(pd.to_numeric, errors = "coerce" ) . fillna(0)
df
# Out:
#    col_one  col_two  col_three
# 0      1.1      4.4        7.7
# 1      2.2      5.5        8.8
# 2      3.3      6.6        0.0

# %%
from glob import glob

# %%
stock_files = sorted(glob ("data/stocks*.csv"))
stock_files
# Out:
# []

# %%
pd.read_clipboard()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
import pandas as pd

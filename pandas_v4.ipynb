# %%
import pandas as pd

# %%
data = {'Company':['Amazon', 'Amazon', 'OpenAI', 'OpenAI', 'Amazon', 'OpenAI', 'Amazon', 'OpenAI'],
        'Department':['IT', 'HR', 'IT', 'HR', 'IT', 'HR', 'HR', 'IT'],
        'Person':['Ahmet', 'Ece', 'Fatma', 'Mehmet', 'Zeynep', 'Ali', 'Yusuf', 'Elif'],
        'Age':[32, 26, 35, 40, 25, 38, 30, 28],
        'Sales':[180, 160, 150, 180, 240, 200, 220, 160]}
data
# Out:
# {'Company': ['Amazon',
#   'Amazon',
#   'OpenAI',
#   'OpenAI',
#   'Amazon',
#   'OpenAI',
#   'Amazon',
#   'OpenAI'],
#  'Department': ['IT', 'HR', 'IT', 'HR', 'IT', 'HR', 'HR', 'IT'],
#  'Person': ['Ahmet',
#   'Ece',
#   'Fatma',
#   'Mehmet',
#   'Zeynep',
#   'Ali',
#   'Yusuf',
#   'Elif'],
#  'Age': [32, 26, 35, 40, 25, 38, 30, 28],
#  'Sales': [180, 160, 150, 180, 240, 200, 220, 160]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
df["Company"]. value_counts()
# Out:
# Company
# Amazon    4
# OpenAI    4
# Name: count, dtype: int64

# %%
df["Company"].unique()
# Out:
# array(['Amazon', 'OpenAI'], dtype=object)

# %%
df.groupby("Company")

# %%
df.groupby("Company").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df.groupby("Company").count()
# Out:
#          Department  Person  Age  Sales
# Company
# Amazon            4       4    4      4
# OpenAI            4       4    4      4

# %%
df.groupby("Company").size()
# Out:
# Company
# Amazon    4
# OpenAI    4
# dtype: int64

# %%
df.groupby("Company").describe()
# Out:
#           Age                                                 Sales         \
#         count   mean       std   min    25%   50%   75%   max count   mean
# Company
# Amazon    4.0  28.25  3.304038  25.0  25.75  28.0  30.5  32.0   4.0  200.0
# OpenAI    4.0  35.25  5.251984  28.0  33.25  36.5  38.5  40.0   4.0  172.5
#
#
#                std    min    25%    50%    75%    max
# Company
# Amazon   36.514837  160.0  175.0  200.0  225.0  240.0
# OpenAI   22.173558  150.0  157.5  170.0  185.0  200.0

# %%
df.groupby("Company").std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.groupby("Company").std()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2641, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    2631     return np.sqrt(
#    2632         self._numba_agg_general(
#    2633             grouped_var,
#    (...)
#    2638         )
#    2639     )
#    2640 else:
# -> 2641     return self._cython_agg_general(
#    2642         "std",
#    2643         alt=lambda x: Series(x, copy=False).std(ddof=ddof),
#    2644         numeric_only=numeric_only,
#    2645         ddof=ddof,
#    2646     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
# ...

# %%
df.groupby("Company").corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.groupby("Company").corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:2734, in DataFrameGroupBy.corr(self, method, min_periods, numeric_only)
#    2727 @doc(DataFrame.corr.__doc__)
#    2728 def corr(
#    2729     self,
#    (...)
#    2732     numeric_only: bool = False,
#    2733 ) -> DataFrame:
# -> 2734     result = self._op_via_apply(
#    2735         "corr", method=method, min_periods=min_periods, numeric_only=numeric_only
#    2736     )
#    2737     return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1425, in GroupBy._op_via_apply(self, name, *args, **kwargs)
#    1422     return self._python_apply_general(curried, self._selected_obj)
#    1424 is_transform = name in base.transformation_kernels
# ...

# %%
df.groupby("Company").max()
# Out:
#         Department  Person  Age  Sales
# Company
# Amazon          IT  Zeynep   32    240
# OpenAI          IT  Mehmet   40    200

# %%
df.groupby("Company").min()
# Out:
#         Department Person  Age  Sales
# Company
# Amazon          HR  Ahmet   25    160
# OpenAI          HR    Ali   28    150

# %%
df.groupby("Company").mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.groupby("Company").mode()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'mode'

# %%
df.groupby("Company").median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df.groupby("Company").sum()
# Out:
#         Department               Person  Age  Sales
# Company
# Amazon    ITHRITHR  AhmetEceZeynepYusuf  113    800
# OpenAI    ITHRHRIT   FatmaMehmetAliElif  141    690

# %%
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
df.groupby("Company")["Sales"].mean()
# Out:
# Company
# Amazon    200.0
# OpenAI    172.5
# Name: Sales, dtype: float64

# %%
df.groupby("Company")["Sales"].sum()
# Out:
# Company
# Amazon    800
# OpenAI    690
# Name: Sales, dtype: int64

# %%
df.groupby("Company")["Sales"].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.groupby("Company")["Sales"].corr()
#
# TypeError: SeriesGroupBy.corr() missing 1 required positional argument: 'other'

# %%
df.groupby("Company")["Sales"].mean()
# Out:
# Company
# Amazon    200.0
# OpenAI    172.5
# Name: Sales, dtype: float64

# %%
df.groupby("Company")[["Sales"]].mean()
# Out:
#          Sales
# Company
# Amazon   200.0
# OpenAI   172.5

# %%
df.groupby("Company")[["Sales"]].sum()
# Out:
#          Sales
# Company
# Amazon     800
# OpenAI     690

# %%
df.groupby("Company")[["Sales"]].agg(["max", "min", "mean"])
# Out:
#         Sales
#           max  min   mean
# Company
# Amazon    240  160  200.0
# OpenAI    200  150  172.5

# %%
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
df.groupby("Company").describe().T
# Out:
# Company          Amazon      OpenAI
# Age   count    4.000000    4.000000
#       mean    28.250000   35.250000
#       std      3.304038    5.251984
#       min     25.000000   28.000000
#       25%     25.750000   33.250000
#       50%     28.000000   36.500000
#       75%     30.500000   38.500000
#       max     32.000000   40.000000
# Sales count    4.000000    4.000000
#       mean   200.000000  172.500000
#       std     36.514837   22.173558
#       min    160.000000  150.000000
#       25%    175.000000  157.500000
#       50%    200.000000  170.000000
#       75%    225.000000  185.000000
#       max    240.000000  200.000000

# %%
df.groupby("Company")[["Sales","Age"]].agg(["min", "max", "mean"]).T
# Out:
# Company     Amazon  OpenAI
# Sales min   160.00  150.00
#       max   240.00  200.00
#       mean  200.00  172.50
# Age   min    25.00   28.00
#       max    32.00   40.00
#       mean   28.25   35.25

# %%
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
# sütun türünü seçme metodu

df.select_dtypes(include = "number")
# Out:
#    Age  Sales
# 0   32    180
# 1   26    160
# 2   35    150
# 3   40    180
# 4   25    240
# 5   38    200
# 6   30    220
# 7   28    160

# %%
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
df.iloc[:, [0,1,2] ]
# Out:
#   Company Department  Person
# 0  Amazon         IT   Ahmet
# 1  Amazon         HR     Ece
# 2  OpenAI         IT   Fatma
# 3  OpenAI         HR  Mehmet
# 4  Amazon         IT  Zeynep
# 5  OpenAI         HR     Ali
# 6  Amazon         HR   Yusuf
# 7  OpenAI         IT    Elif

# %%
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.groupby("pclass")[["age"]].mean()
# Out:
#               age
# pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
df.groupby("pclass")[["age"]].max()
# Out:
#          age
# pclass
# 1       80.0
# 2       70.0
# 3       74.0

# %%
df.groupby("pclass")[["age"]].min()
# Out:
#          age
# pclass
# 1       0.92
# 2       0.67
# 3       0.42

# %%
df.groupby(["pclass","sex"])[["age"]].mean()
# Out:
#                      age
# pclass sex
# 1      female  34.611765
#        male    41.281386
# 2      female  28.722973
#        male    30.740707
# 3      female  21.750000
#        male    26.507589

# %%
data = {'Company':['Amazon', 'Amazon', 'OpenAI', 'OpenAI', 'Amazon', 'OpenAI', 'Amazon', 'OpenAI'],
        'Department':['IT', 'HR', 'IT', 'HR', 'IT', 'HR', 'HR', 'IT'],
        'Person':['Ahmet', 'Ece', 'Fatma', 'Mehmet', 'Zeynep', 'Ali', 'Yusuf', 'Elif'],
        'Age':[32, 26, 35, 40, 25, 38, 30, 28],
        'Sales':[180, 160, 150, 180, 240, 200, 220, 160]}
df = pd.DataFrame(data)
df
# Out:
#   Company Department  Person  Age  Sales
# 0  Amazon         IT   Ahmet   32    180
# 1  Amazon         HR     Ece   26    160
# 2  OpenAI         IT   Fatma   35    150
# 3  OpenAI         HR  Mehmet   40    180
# 4  Amazon         IT  Zeynep   25    240
# 5  OpenAI         HR     Ali   38    200
# 6  Amazon         HR   Yusuf   30    220
# 7  OpenAI         IT    Elif   28    160

# %%
df.filter(["Company","Person"])
# Out:
#   Company  Person
# 0  Amazon   Ahmet
# 1  Amazon     Ece
# 2  OpenAI   Fatma
# 3  OpenAI  Mehmet
# 4  Amazon  Zeynep
# 5  OpenAI     Ali
# 6  Amazon   Yusuf
# 7  OpenAI    Elif

# %%
df = sns.load_dataset("titanic")
df.sample(8)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 415         0       3  female   NaN      0      0   8.0500        S   Third
# 170         0       1    male  61.0      0      0  33.5000        S   First
# 139         0       1    male  24.0      0      0  79.2000        C   First
# 324         0       3    male   NaN      8      2  69.5500        S   Third
# 824         0       3    male   2.0      4      1  39.6875        S   Third
# 508         0       3    male  28.0      0      0  22.5250        S   Third
# 670         1       2  female  40.0      1      1  39.0000        S  Second
# 549         1       2    male   8.0      1      1  36.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 415  woman       False  NaN  Southampton    no   True
# 170    man        True    B  Southampton    no   True
# 139    man        True    B    Cherbourg    no   True
# 324    man        True  NaN  Southampton    no  False
# ...

# %%
df[df["fare"] >= 300]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
df.filter(["pclass", "age"])
# Out:
#      pclass   age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
df.filter(like = "o" , axis = 1)
# Out:
#        who  embark_town  alone
# 0      man  Southampton  False
# 1    woman    Cherbourg  False
# 2    woman  Southampton   True
# 3    woman  Southampton  False
# 4      man  Southampton   True
# ..     ...          ...    ...
# 886    man  Southampton   True
# 887  woman  Southampton   True
# 888  woman  Southampton  False
# 889    man    Cherbourg   True
# 890    man   Queenstown   True
#
# [891 rows x 3 columns]

# %%
new_df = df.filter(["embarked" , "age" , "alone"])
new_df
# Out:
#     embarked   age  alone
# 0          S  22.0  False
# 1          C  38.0  False
# 2          S  26.0   True
# 3          S  35.0  False
# 4          S  35.0   True
# ..       ...   ...    ...
# 886        S  27.0   True
# 887        S  19.0   True
# 888        S   NaN  False
# 889        C  26.0   True
# 890        Q  32.0   True
#
# [891 rows x 3 columns]

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 677         1       3  female  18.0      0      0   9.8417        S   Third
# 786         1       3  female  18.0      0      0   7.4958        S   Third
# 844         0       3    male  17.0      0      0   8.6625        S   Third
# 769         0       3    male  32.0      0      0   8.3625        S   Third
# 546         1       2  female  19.0      1      0  26.0000        S  Second
# 324         0       3    male   NaN      8      2  69.5500        S   Third
# 328         1       3  female  31.0      1      1  20.5250        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 436         0       3  female  21.0      2      2  34.3750        S   Third
# 458         1       2  female  50.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 677  woman       False  NaN  Southampton   yes   True
# ...

# %%
df.query("pclass == 2 & age > 58 & survived == 1")
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 570         1       2  male  62.0      0      0  10.5        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 570        True  NaN  Southampton   yes   True

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

# B sütunu 5'ten büyük olan yerleri koru, diğerlerini NaN yap
result = df.where(df['B'] > 5)
print(result)
# Out:
#      A    B    C
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  3.0  6.0  9.0

# %%
df.where (df["A"] > 3 , other = "go away" )
# Out:
#          A        B        C
# 0  go away  go away  go away
# 1  go away  go away  go away
# 2  go away  go away  go away
